# %%
from models import *
from training import *
from data_pipeline import *

from torch import optim

torch.set_default_dtype(torch.double)

# %% [markdown]
# ## create model, dataset, & optimizer

# %%
impainting_model = Impaint()
optimizer = optim.Adam(impainting_model.parameters(), lr=0.01)

ghcn = GHCN("20180101", "20181231", ["TMAX"], graph_freezing=1)
sampler = Sampler(times=1000, size=200)
ghcn_impainter = GHCNImpainter(ghcn, sampler)

# %%
train_impainter(impainting_model, ghcn_impainter, optimizer, "20180101", "20180101", 3)
# Out:
# ---previous Laplacian expired or no previous Laplacian; building new---
# Found 12074 stations in total in date range 20180101-20180101
# Successfully converged after 106 steps
# Difference between ML @ v and lambda * v:  6.4364549985282995
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 0; LOSS: 53116.58500785565
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 1; LOSS: 43646.66162989622
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 2; LOSS: 299574.95074825606
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 3; LOSS: 46763.03835407076
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 4; LOSS: 49788.086372400954
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 5; LOSS: 47855.07714893669
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 6; LOSS: 43560.15623823085
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 7; LOSS: 51796.99327290019
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 8; LOSS: 47191.96477428431
# EPOCH: 0; BATCH_IDX: 0; RESAMPLING_IDX: 9; LOSS: 45251.60924496295
# ...
